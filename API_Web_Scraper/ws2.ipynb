# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
pd.set_option("display.max_columns", None)

data = pd.read_excel("nba_player_data.xlsx")
data.sample(10)
# Out:
#          Year       Season_Type  PLAYER_ID  RANK          PLAYER     TEAM_ID  \
# 2917  2019-20          Playoffs     201935     4    James Harden  1610612745
# 2530  2018-19          Playoffs     203932    33    Aaron Gordon  1610612753
# 796   2014-15  Regular%20Season     201569    70     Eric Gordon  1610612740
# 1586  2016-17  Regular%20Season    1626164    25    Devin Booker  1610612756
# 3041  2019-20          Playoffs       2738   128  Andre Iguodala  1610612748
# 2289  2018-19  Regular%20Season     203991    50    Clint Capela  1610612745
# 3030  2019-20          Playoffs     202954   117  Brad Wanamaker  1610612738
# 1126  2014-15          Playoffs     201973   133   Jonas Jerebko  1610612738
# 2365  2018-19  Regular%20Season     203939   126   Dwight Powell  1610612742
# 1281  2015-16  Regular%20Season     203458   145        Alex Len  1610612756
#
#      TEAM  GP   MIN  FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  \
# 2917  HOU  12  37.3  9.1  19.0   0.478   3.3   9.8    0.333  8.2  9.7   0.845
# 2530  ORL   5  32.8  5.8  12.4   0.468   1.6   4.0    0.400  2.0  3.8   0.526
# 796   NOP  61  33.1  4.7  11.4   0.411   2.3   5.2    0.448  1.8  2.2   0.805
# 1586  PHX  78  35.0  7.8  18.3   0.423   1.9   5.2    0.363  4.7  5.7   0.832
# 3041  MIA  21  19.5  1.4   3.1   0.462   0.7   1.9    0.359  0.2  0.3   0.714
# 2289  HOU  67  33.6  7.1  10.9   0.648   0.0   0.0    0.000  2.5  3.9   0.636
# 3030  BOS  17  16.1  1.7   3.5   0.483   0.7   1.6    0.444  0.8  0.9   0.875
# 1126  BOS   4  17.0  1.3   3.8   0.333   0.0   1.0    0.000  0.3  0.5   0.500
# 2365  DAL  77  21.6  3.8   6.3   0.597   0.5   1.6    0.307  2.5  3.3   0.772
# 1281  PHX  78  23.3  3.4   8.0   0.423   0.0   0.1    0.143  2.2  3.1   0.728
#
#       OREB  DREB   REB  AST  STL  BLK  TOV   PTS   EFF
# 2917   1.0   4.6   5.6  7.7  1.5  0.8  3.8  29.6  30.0
# 2530   2.2   5.0   7.2  3.6  1.2  0.2  2.6  15.2  16.4
# 796    0.5   2.1   2.6  3.8  0.8  0.2  2.0  13.4  11.7
# 1586   0.6   2.6   3.2  3.4  0.9  0.3  3.1  22.1  15.3
# 3041   0.5   2.0   2.6  1.5  0.8  0.6  0.7   3.8   6.8
# 2289   4.4   8.2  12.7  1.4  0.7  1.5  1.4  16.6  26.2
# 3030   0.1   1.9   2.0  1.8  0.7  0.2  1.1   4.9   6.6
# 1126   1.0   2.5   3.5  0.3  0.5  0.3  0.8   2.8   3.8
# 2365   1.8   3.5   5.3  1.5  0.6  0.6  0.9  10.6  14.4
# 1281   2.3   5.3   7.6  1.2  0.5  0.8  1.9   9.0  11.8

# %%
data.shape
# Out:
# (4210, 27)

# %%
# which player stats are correlated with each other?
# how are minutes played distributed?
# how has the game changed over the past 10 years? Regular season vs playoffs
